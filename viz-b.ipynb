# %% [markdown]
# ### Import libraries

# %% [markdown]
# # Lab: 14 - Data Visualization
#
# # Saadoun M Aldhirat

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### load DataFrame

# %%
df = pd.read_csv('LinearRegression.csv')

# %% [markdown]
# ### plot data using seaborn
# ##### data is linear

# %%
sns.lmplot(x='X', y='Y', data=df)

# %% [markdown]
# ### plot data using seaborn
# ##### data is linear

# %%
with sns.axes_style('white'):
    sns.jointplot('X','Y', df,kind='kde')
# Out:
# /home/saadoun/Desktop/Asac/lab14/Data-Visualization/.venv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 1. Data is linear
#
# 2. Plotting using seaborn, is much easier than using matplotlib
